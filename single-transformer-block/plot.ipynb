# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=2000, noise=0.25, random_state=42)

plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', s=10)
plt.title("Two Moons Dataset")
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

def create_spiral_dataset(n_points=2000, n_classes=4, noise=0.3):
    X, y = [], []

    for class_id in range(n_classes):
        r = np.linspace(0, 5, n_points // n_classes)

        t = (
            np.linspace(
                class_id * 4,
                (class_id + 1) * 4,
                n_points // n_classes
            )
            + np.random.randn(n_points // n_classes) * noise
        )

        x1 = r * np.sin(t * 2.0)
        x2 = r * np.cos(t * 2.0)

        X.append(np.column_stack([x1, x2]))
        y.append(np.full(n_points // n_classes, class_id))

    return np.vstack(X), np.hstack(y)

X, y = create_spiral_dataset(
    n_points=2000,
    n_classes=4,
    noise=0.3
)

plt.figure(figsize=(8, 8))
plt.scatter(
    X[:, 0],
    X[:, 1],
    c=y,
    cmap='tab10',
    s=10,
    alpha=0.7
)

plt.title("4-Class Spiral Dataset")
plt.xlabel("x1")
plt.ylabel("x2")
plt.axis("equal")
plt.show()
