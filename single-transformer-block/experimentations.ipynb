# %%
import torch
import matplotlib.pyplot 
losses=torch.load("losses.pt",map_location='cpu')
gradient_norm=torch.load("gradient_norm.pt",map_location='cpu')
per_layer_activation_norm=torch.load("per_layer_activation_norm.pt",map_location='cpu')
per_layer_activation_mean=torch.load("per_layer_activation_mean.pt",map_location='cpu')
per_layer_activation_std=torch.load("per_layer_activation_std.pt",map_location='cpu')
per_layer_max_value=torch.load("per_layer_max_value.pt",map_location='cpu')
per_layer_gradient_norm=torch.load("per_layer_gradient_norm.pt",map_location='cpu')
# Out:
# /tmp/ipykernel_2680/43775667.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   losses=torch.load("losses.pt",map_location='cpu')
# ...

# %%
print(per_layer_activation_norm)
# Out:
# [{'h.0': 4.673561306844931e-06, 'h.1': 2.4538415441781523e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 0.5320766568183899}, {'h.0': 6.7431719799060374e-06, 'h.1': 3.1705760087263646e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 5.630645751953125}, {'h.0': 1.0718131306930445e-05, 'h.1': 4.657934431241639e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 10.987664222717285}, {'h.0': 1.6946329196798615e-05, 'h.1': 4.4420230860085577e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 16.587554931640625}, {'h.0': 2.506040982552804e-05, 'h.1': 6.906797972651191e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 22.35691261291504}
# ...

# %%
print(gradient_norm)
# Out:
# [0.08235554229312547, 0.15639299098088752, 0.2704911500140441, 0.4023155508066455, 0.5292748239013032, 0.6591442314078452, 0.7965105710064478, 0.917269407106882, 1.0532707849752863, 1.1699508606085511, 1.2769921209612973, 1.3745473386170515, 1.4507324938523563, 1.5069091918751496, 1.5122144955730146, 1.5372804112747613, 1.5022763461298232, 1.4757185673767794, 1.3665448463101333, 1.2669953386347845]

# %%
print(per_layer_activation_norm)
# Out:
# [{'h.0': 4.673561306844931e-06, 'h.1': 2.4538415441781523e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 0.5320766568183899}, {'h.0': 6.7431719799060374e-06, 'h.1': 3.1705760087263646e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 5.630645751953125}, {'h.0': 1.0718131306930445e-05, 'h.1': 4.657934431241639e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 10.987664222717285}, {'h.0': 1.6946329196798615e-05, 'h.1': 4.4420230860085577e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 16.587554931640625}, {'h.0': 2.506040982552804e-05, 'h.1': 6.906797972651191e-17, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 22.35691261291504}
# ...

# %%
print(per_layer_gradient_norm)
# Out:
# [{'h.0': 0.0, 'h.1': 0.0, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 0.08235554229312547}, {'h.0': 0.0, 'h.1': 0.0, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 0.15596655528130024}, {'h.0': 0.0, 'h.1': 0.0, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 0.26944875145667324}, {'h.0': 0.0, 'h.1': 0.0, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 0.40038478195765104}, {'h.0': 0.0, 'h.1': 0.0, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 0.5269383320241356}, {'h.0': 0.0, 'h.1': 0.0, 'h.2': 0.0, 'h.3': 0.0, 'h.4': 0.0, 'h.5': 0.0, 'h.6': 0.0, 'h.7': 0.0, 'h.8': 0.0, 'h.9': 0.0, 'h.10': 0.0, 'h.11': 0.6564644054574699}, {'h.0': 0.0, 'h
# ...
